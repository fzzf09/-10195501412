# %%
 with open("E:\mapreduce\input\input2.txt","w") as f:
     for i in range(5):
         f.writelines(str(i+1)+" "+str(i)+'\n')

# %%
 with open("E:\mapreduce\input\input1.txt","w") as f:
     for i in range(100):
         f.writelines(str(i)+" "+str(i%5+1)+'\n')

# %%
import numpy as np
import matplotlib.pyplot as plt


x = [0, 1000,5000,10000,50000,100000,500000,1000000,2000000,3000000,4000000,5000000]
y1=[0,19,19,19,19,20,21,22,26,31,36,45]
plt.xticks([r for r in x], x, fontsize=18, rotation=20)
plt.figure(1)
plt.subplot(211)
plt.plot(x,y1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
#epoch,acc,loss,val_acc,val_loss
x_axis_data = [0, 1000,5000,10000,50000,100000,500000,1000000,2000000,3000000,4000000,5000000]
y_axis_data1 = [0,19,19,19,19,20,21,22,26,31,36,45]
y_axis_data2 = [0,11,11,11,11,12,12,13,14,15,16,17]
num=['0','1000','5000','10000','50000','100000','500000','1000000','2000000','3000000','4000000','5000000']    
#画图 
fig = plt.figure(figsize=(10, 8))
plt.plot(num, y_axis_data1, 'o-', alpha=0.5,  label='mapjoin')#'
plt.plot(num, y_axis_data2, 'o-', alpha=0.5,  label='mapjoinbroadcast')

 
plt.legend()
 
plt.show()

# %%
x_axis_data = [0, 1000,5000,10000,50000,100000,500000,1000000,2000000,3000000,4000000,5000000]
y_axis_data1 = [0,19,19,19,19,20,21,22,26,31,36,45]
y_axis_data2 = [0,11,11,11,11,12,12,13,14,15,16,17]
y_axis_data3 = [0,19,19,19,19,21,22,26,33,40,49,60]
y_axis_data4 = [0,11,11,11,11,12,12,13,14,15,16,17]
num=['0','1000','5000','10000','50000','100000','500000','1000000','2000000','3000000','4000000','5000000']    
#画图 
fig = plt.figure(figsize=(10, 8))
plt.plot(num, y_axis_data1, 'o-', alpha=0.5,  label='mapjoin')#'
plt.plot(num, y_axis_data2, 'o-', alpha=0.5,  label='mapjoinbroadcast')
plt.plot(num, y_axis_data3, 'o-', alpha=0.5,  label='mapjoin-1')#'
plt.plot(num, y_axis_data4, 'o-', alpha=0.5,  label='mapjoinbroadcast-1')

 
plt.legend()
 
plt.show()
